# %% [markdown]
# # Prediction on a Supernova
# This notebook makes prediction of the element abundance and photosphere velocity and luminosity of a supernova, with a given spectrum and explosion time and a grid of density parameters.
# Firstly, if you have a GPU or want to do the predictions on CPU, please change the "os.environ['CUDA\_VISIBLE\_DEVICES']" line.

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES']='0'

import sys
import time
import tqdm
import glob
import yaml
import keras
import astropy
import numpy as np
import pandas as pd
import tensorflow as tf
import keras.backend as K
import astropy.units as u
import astropy.constants as c
import matplotlib.pyplot as plt
#from keras.optimizers import adam
from scipy.signal import savgol_filter
from keras.models import Sequential,Model
from keras.callbacks import EarlyStopping
#import keras.backend.tensorflow_backend as KTF
from dust_extinction.averages import GCC09_MWAvg
from scipy.ndimage.filters import gaussian_filter1d
from sklearn.model_selection import train_test_split
from scipy.interpolate import interp1d,UnivariateSpline
from dust_extinction.parameter_averages import CCM89,F99
from keras.callbacks import TerminateOnNaN,EarlyStopping,ModelCheckpoint
from keras.layers import Dense,Dropout,LocallyConnected1D,AveragePooling1D,Flatten,Layer,Reshape
from keras.layers import Input,Conv1D,MaxPooling1D,BatchNormalization,Activation,Add,UpSampling1D,Concatenate

from GaussianNetworkKit import *
# Out:
# /tmp/ipykernel_197951/1328897859.py:25: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter1d

# %% [markdown]
# # The Observation
# A list of the supernovae included in the paper are stored in the file "dm15WithDens.csv". You can take a look at this list and see which supernova is interesting.

# %%
wave=np.genfromtxt('Prim.ascii')[:,0]
dm15List=pd.read_csv('dm15WithDens.csv',index_col=0)
#snIndexer=int(sys.argv[1])

def Normalizer(spec,shortwave=6500,longwave=7500):
    small=np.argmin(abs(spec[:,0]-shortwave))
    long=np.argmin(abs(spec[:,0]-longwave))
    if small<long:spec[:,1]=spec[:,1]/np.average(spec[small:long,1])
    if small>long:spec[:,1]=spec[:,1]/np.average(spec[long:small,1])
    return spec
def windowSpec(spec):
    spFunc=interp1d(spec[:,0],spec[:,1],fill_value=np.nan,bounds_error=False)
    smFlux=spFunc(wave)
    smFlux=smFlux/np.nanmean(smFlux)
    smFlux[np.isnan(smFlux)]=-1
    return np.array([wave,smFlux]).T
def specListMaker(starTableDir,redshift,extMW=0,extHost=0,telNameGetter=False):
    starTable=pd.read_csv(starTableDir+'starTable.csv')#'../ObserveSpectra/GoodSpec/SN2011fe/starTable.csv'
    X_snemo=[]
    timeCollect=[]
    telNameList=[]
    for i in range(len(starTable)):
        if starTable['Phase'][i]>20 or starTable['Phase'][i]<-10:continue
        fileName=starTable['Ascii file'].iloc[i]
        fileName=glob.glob(starTableDir+fileName.split('.dat')[0]+'*')[0]
        spec=np.genfromtxt(fileName)
        spec[:,1]=spec[:,1]/GCC09_MWAvg().extinguish(spec[:,0]*u.Angstrom,Ebv=extMW)
        spec[:,0]=spec[:,0]/(1+redshift)
        spec[:,1]=spec[:,1]/F99().extinguish(spec[:,0]*u.Angstrom,Ebv=extHost)
        spec=Normalizer(spec)
        spResa=windowSpec(spec)
        if np.max(spResa[:,1])>20:continue
        X_snemo.append(spResa[:,1].reshape([2000,1]))
        timeCollect.append(starTable['Phase'][i])
        if telNameGetter:
            telNameList.append(starTable['Tel'][i])
    X_snemo=np.array(X_snemo)
    timeCollect=np.array(timeCollect)+19
    if telNameGetter:
        return X_snemo,timeCollect,telNameList
    else:
        return X_snemo,timeCollect

# %% [markdown]
# # The Training Data Set
# Reads the training and testing data set into the program, but not really used. The "YauxNorm" will be used to reconstruct the real luminosity and explosion time and photosphere velocity from neural network predictions.

# %%
X_train=np.load('../1_Generate/DataSet/110KRun/X_train.npy')
X_test=np.load('../1_Generate/DataSet/110KRun/X_test.npy')
Y_train=np.load('../1_Generate/DataSet/110KRun/Y_train.npy')
Y_test=np.load('../1_Generate/DataSet/110KRun/Y_test.npy')
Yaux_train=np.load('../1_Generate/DataSet/110KRun/Yaux_train.npy')
Yaux_test=np.load('../1_Generate/DataSet/110KRun/Yaux_test.npy')
YauxNorm=np.load('../1_Generate/DataSet/110KRun/YauxNorm.npy')

# %%
def MRNNSoftMaxESMake(CellNumber=7,outter=0,X_train=X_train,X_test=X_test,Y_train=Y_train,Y_test=Y_test,Yaux_train=Yaux_train,Yaux_test=Yaux_test):
    INput=Input(shape=(X_train.shape[1],1,))
    conv1=Conv1D(8,15,strides=2,padding='same')(INput)
    conv1=Conv1D(16,3,strides=1,padding='same')(conv1)
    batc1=BatchNormalization()(conv1)
    acti1=Activation('selu')(batc1)
    pool1=MaxPooling1D(2)(acti1)
    
    conv2=Conv1D(8,1)(pool1)
    batc2=BatchNormalization()(conv2)
    acti2=Activation('selu')(batc2)
    conv3=Conv1D(16,3,padding='same')(acti2)
    
    adds=[pool1]
    
    addi=Add()(adds+[conv3])
    adds.append(addi)
    
    for i in range(CellNumber):
        conv2=Conv1D(8,1)(addi)
        batc2=BatchNormalization()(conv2)
        acti2=Activation('selu')(batc2)
        conv3=Conv1D(16,3,padding='same')(acti2)
        addi=Add()(adds+[conv3])
        adds.append(addi)
    
    batc2=BatchNormalization()(addi)
    
    flat1=keras.layers.Flatten()(batc2)
    drop1=Dropout(0.2)(flat1)
    dens1=Dense(256,activation='selu')(drop1)
    
    INput2=Input(shape=(3,))
    dens2=Dense(6,activation='selu')(INput2)
    dens2=Dense(9,activation='selu')(dens2)
    conc1=Concatenate()([INput2,dens2])
    dens2=Dense(21,activation='selu')(conc1)
    conc1=Concatenate()([INput2,dens2])
    dens2=Dense(45,activation='selu')(conc1)
    conc1=Concatenate()([INput2,dens2])
    
    conc2=Concatenate()([conc1,dens1])
    dens3=Dense(384,activation='selu')(conc2)
    drop2=Dropout(0.2)(dens3)
    
    dens3=Dense(256,activation='selu')(drop2)
    dens3=Dense(256,activation='selu')(dens3)
    dens3=Dense(256,activation='selu')(dens3)
    dens3=Dense(256,activation='selu')(dens3)
    
    if outter==6:mu,sig=GaussianLayer(2,name='ld_out')(dens3)
    else:mu,sig=GaussianLayer(30,hardMax=False,name='zone_'+str(outter)+'_out')(dens3)
    model=Model(inputs=[INput,INput2],outputs=mu)
    print(model.summary())
    opt=keras.optimizers.Adam(lr=0.00003,decay=1e-6)
    model.compile(optimizer=opt,loss=custom_loss(sig))
    return model

# %% [markdown]
# # The Neural Network
# The neural network parameters are read here. I refer to the neural network loss function metrics to find the best performance neural networks. There are 7 neural networks in total, 6 for element abundances, the other is for the luminosity, etc.

# %%
intermediateModels=[]
for outter in range(7):
    valiLossList=[]
    for mdInd in range(10):
        try:
            his2=pd.read_csv('../2_Train/Metric/110KLogML/ES_'+str(outter)+'_'+str(mdInd)+'_His2.csv')
            valiLoss=his2['val_loss'].iloc[-1]
            if np.isnan(valiLoss):valiLoss=np.inf
        except:valiLoss=np.inf
        valiLossList.append(valiLoss)
    mdIndChos=np.argmin(valiLossList)
    model=MRNNSoftMaxESMake(outter=outter)
    model.load_weights('../2_Train/MdSaver/110KLogML/Model_'+str(outter)+'_'+str(mdIndChos)+'.hdf')
    if outter==6:
        outLayerName='ld_out'
    else:outLayerName='zone_'+str(outter)+'_out'
    intermediateModels.append(K.function(inputs=[model.input[0],model.input[1]],outputs=model.get_layer(outLayerName).output))
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 2000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_126 (Conv1D)             (None, 1000, 8)      128         input_15[0][0]
# __________________________________________________________________________________________________
# conv1d_127 (Conv1D)             (None, 1000, 16)     400         conv1d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 1000, 16)     64          conv1d_127[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 1000, 16)     0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 500, 16)      0           activation_63[0][0]
# __________________________________________________________________________________________________
# conv1d_128 (Conv1D)             (None, 500, 8)       136         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 500, 8)       32          conv1d_128[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 500, 8)       0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv1d_129 (Conv1D)             (None, 500, 16)      400         activation_64[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  conv1d_129[0][0]
# __________________________________________________________________________________________________
# conv1d_130 (Conv1D)             (None, 500, 8)       136         add_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 500, 8)       32          conv1d_130[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 500, 8)       0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv1d_131 (Conv1D)             (None, 500, 16)      400         activation_65[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  conv1d_131[0][0]
# __________________________________________________________________________________________________
# conv1d_132 (Conv1D)             (None, 500, 8)       136         add_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 500, 8)       32          conv1d_132[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 500, 8)       0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_133 (Conv1D)             (None, 500, 16)      400         activation_66[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  conv1d_133[0][0]
# __________________________________________________________________________________________________
# conv1d_134 (Conv1D)             (None, 500, 8)       136         add_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 500, 8)       32          conv1d_134[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 500, 8)       0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv1d_135 (Conv1D)             (None, 500, 16)      400         activation_67[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  add_58[0][0]
#                                                                  conv1d_135[0][0]
# __________________________________________________________________________________________________
# conv1d_136 (Conv1D)             (None, 500, 8)       136         add_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 500, 8)       32          conv1d_136[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 500, 8)       0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv1d_137 (Conv1D)             (None, 500, 16)      400         activation_68[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  add_58[0][0]
#                                                                  add_59[0][0]
#                                                                  conv1d_137[0][0]
# __________________________________________________________________________________________________
# conv1d_138 (Conv1D)             (None, 500, 8)       136         add_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 500, 8)       32          conv1d_138[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 500, 8)       0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv1d_139 (Conv1D)             (None, 500, 16)      400         activation_69[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  add_58[0][0]
#                                                                  add_59[0][0]
#                                                                  add_60[0][0]
#                                                                  conv1d_139[0][0]
# __________________________________________________________________________________________________
# conv1d_140 (Conv1D)             (None, 500, 8)       136         add_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 500, 8)       32          conv1d_140[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 500, 8)       0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv1d_141 (Conv1D)             (None, 500, 16)      400         activation_70[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  add_58[0][0]
#                                                                  add_59[0][0]
#                                                                  add_60[0][0]
#                                                                  add_61[0][0]
#                                                                  conv1d_141[0][0]
# __________________________________________________________________________________________________
# conv1d_142 (Conv1D)             (None, 500, 8)       136         add_62[0][0]
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 3)]          0
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 500, 8)       32          conv1d_142[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 6)            24          input_16[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 500, 8)       0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 9)            63          dense_71[0][0]
# __________________________________________________________________________________________________
# conv1d_143 (Conv1D)             (None, 500, 16)      400         activation_71[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 12)           0           input_16[0][0]
#                                                                  dense_72[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 500, 16)      0           max_pooling1d_7[0][0]
#                                                                  add_56[0][0]
#                                                                  add_57[0][0]
#                                                                  add_58[0][0]
#                                                                  add_59[0][0]
#                                                                  add_60[0][0]
#                                                                  add_61[0][0]
#                                                                  add_62[0][0]
#                                                                  conv1d_143[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 21)           273         concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 500, 16)      64          add_63[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 24)           0           input_16[0][0]
#                                                                  dense_73[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 8000)         0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 45)           1125        concatenate_29[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 8000)         0           flatten_7[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 48)           0           input_16[0][0]
#                                                                  dense_74[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 256)          2048256     dropout_14[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 304)          0           concatenate_30[0][0]
#                                                                  dense_70[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 384)          117120      concatenate_31[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 384)          0           dense_75[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 256)          98560       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 256)          65792       dense_76[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 256)          65792       dense_77[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 256)          65792       dense_78[0][0]
# __________________________________________________________________________________________________
# zone_0_out (GaussianLayer)      [(None, 30), (None,  15420       dense_79[0][0]
# ==================================================================================================
# Total params: 2,483,417
# Trainable params: 2,483,225
# Non-trainable params: 192
# __________________________________________________________________________________________________
# None
# 2022-10-11 13:18:05.911878: W tensorflow/core/util/tensor_slice_reader.cc:95] Could not open ../2_Train/MdSaver/110KLogML/Model_0_1.hdf: Data loss: not an sstable (bad magic number): perhaps your file is in a different file format and you need to use a different restore operator?
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 2000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_144 (Conv1D)             (None, 1000, 8)      128         input_17[0][0]
# __________________________________________________________________________________________________
# conv1d_145 (Conv1D)             (None, 1000, 16)     400         conv1d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 1000, 16)     64          conv1d_145[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 1000, 16)     0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 500, 16)      0           activation_72[0][0]
# __________________________________________________________________________________________________
# conv1d_146 (Conv1D)             (None, 500, 8)       136         max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 500, 8)       32          conv1d_146[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 500, 8)       0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv1d_147 (Conv1D)             (None, 500, 16)      400         activation_73[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  conv1d_147[0][0]
# __________________________________________________________________________________________________
# conv1d_148 (Conv1D)             (None, 500, 8)       136         add_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 500, 8)       32          conv1d_148[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 500, 8)       0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv1d_149 (Conv1D)             (None, 500, 16)      400         activation_74[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  conv1d_149[0][0]
# __________________________________________________________________________________________________
# conv1d_150 (Conv1D)             (None, 500, 8)       136         add_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 500, 8)       32          conv1d_150[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 500, 8)       0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv1d_151 (Conv1D)             (None, 500, 16)      400         activation_75[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  conv1d_151[0][0]
# __________________________________________________________________________________________________
# conv1d_152 (Conv1D)             (None, 500, 8)       136         add_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 500, 8)       32          conv1d_152[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 500, 8)       0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, 500, 16)      400         activation_76[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  add_66[0][0]
#                                                                  conv1d_153[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, 500, 8)       136         add_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 500, 8)       32          conv1d_154[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 500, 8)       0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, 500, 16)      400         activation_77[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  add_66[0][0]
#                                                                  add_67[0][0]
#                                                                  conv1d_155[0][0]
# __________________________________________________________________________________________________
# conv1d_156 (Conv1D)             (None, 500, 8)       136         add_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 500, 8)       32          conv1d_156[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 500, 8)       0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv1d_157 (Conv1D)             (None, 500, 16)      400         activation_78[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  add_66[0][0]
#                                                                  add_67[0][0]
#                                                                  add_68[0][0]
#                                                                  conv1d_157[0][0]
# __________________________________________________________________________________________________
# conv1d_158 (Conv1D)             (None, 500, 8)       136         add_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 500, 8)       32          conv1d_158[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 500, 8)       0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv1d_159 (Conv1D)             (None, 500, 16)      400         activation_79[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  add_66[0][0]
#                                                                  add_67[0][0]
#                                                                  add_68[0][0]
#                                                                  add_69[0][0]
#                                                                  conv1d_159[0][0]
# __________________________________________________________________________________________________
# conv1d_160 (Conv1D)             (None, 500, 8)       136         add_70[0][0]
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 3)]          0
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 500, 8)       32          conv1d_160[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 6)            24          input_18[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 500, 8)       0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 9)            63          dense_81[0][0]
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, 500, 16)      400         activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 12)           0           input_18[0][0]
#                                                                  dense_82[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 500, 16)      0           max_pooling1d_8[0][0]
#                                                                  add_64[0][0]
#                                                                  add_65[0][0]
#                                                                  add_66[0][0]
#                                                                  add_67[0][0]
#                                                                  add_68[0][0]
#                                                                  add_69[0][0]
#                                                                  add_70[0][0]
#                                                                  conv1d_161[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 21)           273         concatenate_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 500, 16)      64          add_71[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 24)           0           input_18[0][0]
#                                                                  dense_83[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 8000)         0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 45)           1125        concatenate_33[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8000)         0           flatten_8[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 48)           0           input_18[0][0]
#                                                                  dense_84[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 256)          2048256     dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 304)          0           concatenate_34[0][0]
#                                                                  dense_80[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 384)          117120      concatenate_35[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 384)          0           dense_85[0][0]
# __________________________________________________________________________________________________
# dense_86 (Dense)                (None, 256)          98560       dropout_17[0][0]
# __________________________________________________________________________________________________
# dense_87 (Dense)                (None, 256)          65792       dense_86[0][0]
# __________________________________________________________________________________________________
# dense_88 (Dense)                (None, 256)          65792       dense_87[0][0]
# __________________________________________________________________________________________________
# dense_89 (Dense)                (None, 256)          65792       dense_88[0][0]
# __________________________________________________________________________________________________
# zone_1_out (GaussianLayer)      [(None, 30), (None,  15420       dense_89[0][0]
# ==================================================================================================
# Total params: 2,483,417
# Trainable params: 2,483,225
# Non-trainable params: 192
# __________________________________________________________________________________________________
# None
# 2022-10-11 13:18:06.322798: W tensorflow/core/util/tensor_slice_reader.cc:95] Could not open ../2_Train/MdSaver/110KLogML/Model_1_0.hdf: Data loss: not an sstable (bad magic number): perhaps your file is in a different file format and you need to use a different restore operator?
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 2000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_162 (Conv1D)             (None, 1000, 8)      128         input_19[0][0]
# __________________________________________________________________________________________________
# conv1d_163 (Conv1D)             (None, 1000, 16)     400         conv1d_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 1000, 16)     64          conv1d_163[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 1000, 16)     0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 500, 16)      0           activation_81[0][0]
# __________________________________________________________________________________________________
# conv1d_164 (Conv1D)             (None, 500, 8)       136         max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 500, 8)       32          conv1d_164[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 500, 8)       0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv1d_165 (Conv1D)             (None, 500, 16)      400         activation_82[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  conv1d_165[0][0]
# __________________________________________________________________________________________________
# conv1d_166 (Conv1D)             (None, 500, 8)       136         add_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 500, 8)       32          conv1d_166[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 500, 8)       0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv1d_167 (Conv1D)             (None, 500, 16)      400         activation_83[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  conv1d_167[0][0]
# __________________________________________________________________________________________________
# conv1d_168 (Conv1D)             (None, 500, 8)       136         add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 500, 8)       32          conv1d_168[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 500, 8)       0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv1d_169 (Conv1D)             (None, 500, 16)      400         activation_84[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  add_73[0][0]
#                                                                  conv1d_169[0][0]
# __________________________________________________________________________________________________
# conv1d_170 (Conv1D)             (None, 500, 8)       136         add_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 500, 8)       32          conv1d_170[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 500, 8)       0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv1d_171 (Conv1D)             (None, 500, 16)      400         activation_85[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  add_73[0][0]
#                                                                  add_74[0][0]
#                                                                  conv1d_171[0][0]
# __________________________________________________________________________________________________
# conv1d_172 (Conv1D)             (None, 500, 8)       136         add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 500, 8)       32          conv1d_172[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 500, 8)       0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv1d_173 (Conv1D)             (None, 500, 16)      400         activation_86[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  add_73[0][0]
#                                                                  add_74[0][0]
#                                                                  add_75[0][0]
#                                                                  conv1d_173[0][0]
# __________________________________________________________________________________________________
# conv1d_174 (Conv1D)             (None, 500, 8)       136         add_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 500, 8)       32          conv1d_174[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 500, 8)       0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv1d_175 (Conv1D)             (None, 500, 16)      400         activation_87[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  add_73[0][0]
#                                                                  add_74[0][0]
#                                                                  add_75[0][0]
#                                                                  add_76[0][0]
#                                                                  conv1d_175[0][0]
# __________________________________________________________________________________________________
# conv1d_176 (Conv1D)             (None, 500, 8)       136         add_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 500, 8)       32          conv1d_176[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 500, 8)       0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv1d_177 (Conv1D)             (None, 500, 16)      400         activation_88[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 500, 16)      0           max_pooling1d_9[0][0]
#                                                                  add_72[0][0]
#                                                                  add_73[0][0]
#                                                                  add_74[0][0]
#                                                                  add_75[0][0]
#                                                                  add_76[0][0]
#                                                                  add_77[0][0]
#                                                                  conv1d_177[0][0]
# __________________________________________________________________________________________________
# conv1d_178 (Conv1D)             (None, 500, 8)       136         add_78[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 3)]          0
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 500, 8)       32          conv1d_178[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 6)            24          input_20[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 500, 8)       0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# dense_92 (Dense)                (None, 9)            63          dense_91[0][0]
# ...
# activation_118 (Activation)     (None, 500, 8)       0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv1d_237 (Conv1D)             (None, 500, 16)      400         activation_118[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  conv1d_237[0][0]
# __________________________________________________________________________________________________
# conv1d_238 (Conv1D)             (None, 500, 8)       136         add_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 500, 8)       32          conv1d_238[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 500, 8)       0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv1d_239 (Conv1D)             (None, 500, 16)      400         activation_119[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  conv1d_239[0][0]
# __________________________________________________________________________________________________
# conv1d_240 (Conv1D)             (None, 500, 8)       136         add_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 500, 8)       32          conv1d_240[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 500, 8)       0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv1d_241 (Conv1D)             (None, 500, 16)      400         activation_120[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  conv1d_241[0][0]
# __________________________________________________________________________________________________
# conv1d_242 (Conv1D)             (None, 500, 8)       136         add_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 500, 8)       32          conv1d_242[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 500, 8)       0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv1d_243 (Conv1D)             (None, 500, 16)      400         activation_121[0][0]
# __________________________________________________________________________________________________
# add_107 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  add_106[0][0]
#                                                                  conv1d_243[0][0]
# __________________________________________________________________________________________________
# conv1d_244 (Conv1D)             (None, 500, 8)       136         add_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 500, 8)       32          conv1d_244[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 500, 8)       0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv1d_245 (Conv1D)             (None, 500, 16)      400         activation_122[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  add_106[0][0]
#                                                                  add_107[0][0]
#                                                                  conv1d_245[0][0]
# __________________________________________________________________________________________________
# conv1d_246 (Conv1D)             (None, 500, 8)       136         add_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 500, 8)       32          conv1d_246[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 500, 8)       0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv1d_247 (Conv1D)             (None, 500, 16)      400         activation_123[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  add_106[0][0]
#                                                                  add_107[0][0]
#                                                                  add_108[0][0]
#                                                                  conv1d_247[0][0]
# __________________________________________________________________________________________________
# conv1d_248 (Conv1D)             (None, 500, 8)       136         add_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 500, 8)       32          conv1d_248[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 500, 8)       0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv1d_249 (Conv1D)             (None, 500, 16)      400         activation_124[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  add_106[0][0]
#                                                                  add_107[0][0]
#                                                                  add_108[0][0]
#                                                                  add_109[0][0]
#                                                                  conv1d_249[0][0]
# __________________________________________________________________________________________________
# conv1d_250 (Conv1D)             (None, 500, 8)       136         add_110[0][0]
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 3)]          0
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 500, 8)       32          conv1d_250[0][0]
# __________________________________________________________________________________________________
# dense_131 (Dense)               (None, 6)            24          input_28[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 500, 8)       0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# dense_132 (Dense)               (None, 9)            63          dense_131[0][0]
# __________________________________________________________________________________________________
# conv1d_251 (Conv1D)             (None, 500, 16)      400         activation_125[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 12)           0           input_28[0][0]
#                                                                  dense_132[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 500, 16)      0           max_pooling1d_13[0][0]
#                                                                  add_104[0][0]
#                                                                  add_105[0][0]
#                                                                  add_106[0][0]
#                                                                  add_107[0][0]
#                                                                  add_108[0][0]
#                                                                  add_109[0][0]
#                                                                  add_110[0][0]
#                                                                  conv1d_251[0][0]
# __________________________________________________________________________________________________
# dense_133 (Dense)               (None, 21)           273         concatenate_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 500, 16)      64          add_111[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 24)           0           input_28[0][0]
#                                                                  dense_133[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 8000)         0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# dense_134 (Dense)               (None, 45)           1125        concatenate_53[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 8000)         0           flatten_13[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 48)           0           input_28[0][0]
#                                                                  dense_134[0][0]
# __________________________________________________________________________________________________
# dense_130 (Dense)               (None, 256)          2048256     dropout_26[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 304)          0           concatenate_54[0][0]
#                                                                  dense_130[0][0]
# __________________________________________________________________________________________________
# dense_135 (Dense)               (None, 384)          117120      concatenate_55[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 384)          0           dense_135[0][0]
# __________________________________________________________________________________________________
# dense_136 (Dense)               (None, 256)          98560       dropout_27[0][0]
# __________________________________________________________________________________________________
# dense_137 (Dense)               (None, 256)          65792       dense_136[0][0]
# __________________________________________________________________________________________________
# dense_138 (Dense)               (None, 256)          65792       dense_137[0][0]
# __________________________________________________________________________________________________
# dense_139 (Dense)               (None, 256)          65792       dense_138[0][0]
# __________________________________________________________________________________________________
# ld_out (GaussianLayer)          [(None, 2), (None, 2 1028        dense_139[0][0]
# ==================================================================================================
# Total params: 2,469,025
# Trainable params: 2,468,833
# Non-trainable params: 192
# __________________________________________________________________________________________________
# None
# 2022-10-11 13:18:08.288246: W tensorflow/core/util/tensor_slice_reader.cc:95] Could not open ../2_Train/MdSaver/110KLogML/Model_6_2.hdf: Data loss: not an sstable (bad magic number): perhaps your file is in a different file format and you need to use a different restore operator?

# %%
def ModelPredictor(modelList,specList,auxInList):
    matExport=np.zeros([len(specList),6,30])
    errExport=np.zeros([len(specList),6,30])
    for j in range(6):
        mu,sigma=modelList[j]([specList,auxInList])
        matExport[:,j,:]=mu
        errExport[:,j,:]=sigma**0.5
    j=6
    mu,sigma=modelList[j]([specList,auxInList])
    sigma=sigma**0.5
    mu[:,0]=mu[:,0]*YauxNorm[1,0]+YauxNorm[0,0]
    mu[:,1]=mu[:,1]*YauxNorm[1,2]+YauxNorm[0,2]
    sigma[:,0]=sigma[:,0]*YauxNorm[1,0]
    sigma[:,1]=sigma[:,1]*YauxNorm[1,2]
    return matExport,errExport,mu,sigma

# %% [markdown]
# # The Spectra
# Here, the program reads all the spectra into the notebook referring to the data stored in "ObserveSpec3No2" folder.
# You can take a look at variable "snNameList" to see which of the supernovae are included.
# Not all the supernovae in the "dm15WithDens.csv" file are included, some may not have spectra between 10 days and 40 days.

# %%
XspecList,timeList,snNameList,dm15ChosL,dm15ErrL=[],[],[],[],[]
for i in range(len(dm15List)):
    snName=dm15List['ObjName'].iloc[i]
    redshift=dm15List['Redshift'].iloc[i]
    if os.path.exists('ObserveSpec3No2/'+snName+'/starTable.csv')==False:continue
    X_snemo,timeCollect=specListMaker('ObserveSpec3No2/'+snName+'/',redshift,extHost=dm15List['EBVhost'].iloc[i],extMW=dm15List['EBVmw'].iloc[i])
    if len(X_snemo)==0:continue
    timeList.append(timeCollect)
    dm15ChosL.append(dm15List['DM15'].iloc[i])
    dm15ErrL.append(dm15List['DM15err'].iloc[i])
    snNameList.append(dm15List['ObjName'].iloc[i])
    XspecList.append(X_snemo)

# %% [markdown]
# # Pick a Supernova
# Here you can pick a supernova, like number 10, to make predictions.
# The density parameter grid is also made at here.

# %%
snIndexer=10
i=snIndexer
densPivotRange=np.arange(0.2,2.01,0.1)
densSlopeRange=np.arange(0,2.01,0.1)

# %% [markdown]
# # Predict
# Here it is the real prediction code. The neural networks will make predictions of the element and auxiliary data and their error bars, and store them into "matBig.npy" (element data), "auxBig.npy" (luminosity, etc), "errBig.npy" (element data error), "aerBig.npy" (luminosity, etc, error). Also, the spectra resampled to the neural network input format is also stored, in the "Xinput.npy" file.

# %%
os.popen('mkdir -p predOutMassive/'+snNameList[i])
X_snemo=XspecList[i]
timeCollect=timeList[i]
matBig=np.zeros([len(densPivotRange),len(densSlopeRange),len(X_snemo),6,30])
errBig=np.zeros([len(densPivotRange),len(densSlopeRange),len(X_snemo),6,30])
auxBig=np.zeros([len(densPivotRange),len(densSlopeRange),len(X_snemo),5])
aerBig=np.zeros([len(densPivotRange),len(densSlopeRange),len(X_snemo),5])
for densNInd,densN in enumerate(densPivotRange):
    for densDInd,densD in enumerate(densSlopeRange):
        densN=float(round(densN,3))
        densD=float(round(densD,3))
        timeNorm=(timeCollect-YauxNorm[0,1])/YauxNorm[1,1]
        timeNorm=timeNorm.reshape([-1,1])
        dens1Norm=(np.ones([len(X_snemo),1])*densN-YauxNorm[0,3])/YauxNorm[1,3]
        dens2Norm=(np.ones([len(X_snemo),1])*densD-YauxNorm[0,4])/YauxNorm[1,4]
        auxIn=np.hstack([timeNorm,dens1Norm,dens2Norm])
        matExport,errExport,mu,sigma=ModelPredictor(intermediateModels,X_snemo,auxIn)

        auxList=np.zeros([len(X_snemo),5])
        auxList[:,0]=mu[:,0]
        auxList[:,2]=mu[:,1]
        auxList[:,1]=timeCollect
        auxList[:,3]=densN
        auxList[:,4]=densD
        sigList=np.zeros([len(X_snemo),5])
        sigList[:,0]=sigma[:,0]
        sigList[:,2]=sigma[:,1]
        matBig[densNInd,densDInd]=matExport
        errBig[densNInd,densDInd]=errExport
        auxBig[densNInd,densDInd]=auxList
        aerBig[densNInd,densDInd]=sigList
matBig=10**matBig
np.save('predOutMassive/'+snNameList[i]+'/matBig.npy',matBig)
np.save('predOutMassive/'+snNameList[i]+'/errBig.npy',errBig)
np.save('predOutMassive/'+snNameList[i]+'/auxBig.npy',auxBig)
np.save('predOutMassive/'+snNameList[i]+'/aerBig.npy',aerBig)
np.save('predOutMassive/'+snNameList[i]+'/Xinput.npy',X_snemo)
